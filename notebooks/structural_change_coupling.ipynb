# %% [markdown]
# # Structural and logical change coupling

# %% [markdown]
# Instructions:
#
# Depending on if run the notebook locally on in a cloud drive:
# * Replace the proj_name and proj_data_folder in the Configuration section
# * Replace the cloud drive folder in the Configuration section

# %% [markdown]
# ## Configuration

# %%
proj_name = 'glucosio-android' # 'PX4-Autopilot' #'PROJ_NAME'
proj_data_folder = '../project_results/' + proj_name + '/'

# %% [markdown]
# ### If you run this notebook in google colaboratory, configure this block.
# You will have to copy the generated database, the folders "notebooks" and "analytics".

# %%
from google.colab import drive
import os

GDRIVE_FOLDER = 'callgraphCA/glucosioExample'  # cloud dri
 
drive.mount('/gdrive')
# the project's folder
drive_folder = '/gdrive/My Drive/' + GDRIVE_FOLDER
os.chdir(drive_folder)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ## Imports

# %%
# !pip install apyori
# https://github.com/ymoch/apyori
# https://medium.com/linkit-intecs/apriori-algorithm-in-data-mining-part-2-590d58e0998b

# !pip install python-stopwatch
# Out:
# Collecting apyori
#   Using cached apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py): started
#   Building wheel for apyori (setup.py): finished with status 'done'
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=f3feac3d1af95f2c3b3e8c7401f3555d012a09827af64f74336367afd4261a8e
#   Stored in directory: c:\users\lopm\appdata\local\pip\cache\wheels\32\2a\54\10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2
# Collecting python-stopwatch
#   Using cached python_stopwatch-1.0.4-py3-none-any.whl (6.5 kB)
# Collecting termcolor
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=5131be7427fb1ce20a21da20f389601862df3bb2799fa7dd33ee3c4950ea34be
#   Stored in directory: c:\users\lopm\appdata\local\pip\cache\wheels\b6\0d\90\0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# Installing collected packages: termcolor, python-stopwatch
# Successfully installed python-stopwatch-1.0.4 termcolor-1.1.0

# %%
import sys
import os
import pandas as pd
import sqlite3
from pathlib import Path

#from apyori import apriori
import apyori
#from stopwatch import Stopwatch, profile
# works with lists, not pandas, no nan values, apostrophe between values of transaction

# min_support -- The minimum support of relations (float).
# min_confidence -- The minimum confidence of relations (float).
# min_lift -- The minimum lift of relations (float).
# max_length -- The maximum length of the relation (integer).

# %%
# CCSD libraries
analytics_folder_path = str(Path.cwd().parents[0] / "analytics")
sys.path.append(analytics_folder_path)

from coupling_association_rules_utils import *

# %%
# Reolads
import importlib
import coupling_association_rules_utils

importlib.reload(coupling_association_rules_utils)
from coupling_association_rules_utils import *

# %% [markdown]
# ## Database connections

# %%
ANALYTICS_DB_PATH =  proj_data_folder + proj_name + '_analytics.db'
print(ANALYTICS_DB_PATH)
print(os.path.isfile(ANALYTICS_DB_PATH))
con_analytics_db = sqlite3.connect(ANALYTICS_DB_PATH)
# Out:
# ../project_results/glucosio-android/glucosio-android_analytics.db
# True

# %% [markdown]
# # Change coupling and structural dependency rates

# %%
## On commit and file level - distinct
sql_statement = """select 
--commit_hash,
GROUP_CONCAT(distinct("'" || file_name|| "'") )  as files_in_hash
from file_commit
group by commit_hash;"""

records, pruned_records, df = get_records(con_analytics_db, 'files_in_hash', sql_statement, 2)
# Out:
# df len:  7
# records len:  7
# pruned_records len:  3

# %%
# for applying the apyori.apriori algorithm the records list must have a specific format
records[0:2]
# Out:
# [["'GlucosioApplication.java'",
#   "'AddA1CActivity.java'",
#   "'AddCholesterolActivity.java'",
#   "'AddKetoneActivity.java'",
#   "'AddPressureActivity.java'",
#   "'AddWeightActivity.java'",
#   "'OverviewFragment.java'",
#   "'OverviewPresenter.java'",
#   "'HelloActivityTest.java'"],
#  ["'MainActivity.java'"]]

# %% [markdown]
# We can observe the differences between applying association rule mining to the whole itemset records or just the ones who are pruned with a minimum number of items (default >2)

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, records, min_confidence=0.1, min_support=0.1)
# Out:
# Nr rules 669, with structural coupling 615, 0.92

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.1, min_support=0.1)
# Out:
# Nr rules 668, with structural coupling 615, 0.92

# %% [markdown]
# The funciton *calculate_structural_coupling_rates* retunrs two lists, the itemsets_list contains itemsets > 2, the rules_list contains all found association rules (including the ones for one item because they show the support of the item in the whole transactions set).

# %%
for r in itemsets_list:
  print(r)
# Out:
# ['A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['GlucosioConverter.java', 'A1cCalculatorActivity.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java']
# ['A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'A1cCalculatorActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java']
# ['AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java']
# ['AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddReadingActivity.java', 'AddA1CActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddA1CActivity.java', 'OverviewFragment.java']
# ['AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddGlucoseActivity.java']
# ['AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddWeightActivity.java', 'AddGlucoseActivity.java']
# ['GlucosioConverter.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'AddGlucoseActivity.java']
# ['AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'AddGlucoseActivity.java']
# ['AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java']
# ['AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddPressureActivity.java']
# ['GlucosioApplication.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'AddPressureActivity.java']
# ['OverviewFragment.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddReadingActivity.java', 'AddWeightActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'OverviewPresenter.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java']
# ['GlucosioApplication.java', 'OverviewFragment.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java']
# ['GlucosioConverter.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'GlucosioConverter.java']
# ['HelloActivityTest.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'ReadingTools.java']
# ['OverviewPresenter.java', 'OverviewFragment.java']
# ['ReadingTools.java', 'OverviewPresenter.java']
# ['GlucosioConverter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['A1cCalculatorActivity.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java']
# ['GlucosioConverter.java', 'A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['ReadingTools.java', 'A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddReadingActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddReadingActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddA1CActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddReadingActivity.java', 'AddA1CActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddA1CActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddGlucoseActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java']
# ['AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddReadingActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'AddGlucoseActivity.java']
# ['GlucosioConverter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'HistoryAdapter.java', 'AddGlucoseActivity.java']
# ['ReadingTools.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddReadingActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddWeightActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'ReadingTools.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'OverviewPresenter.java']
# ['HelloActivityTest.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HistoryAdapter.java', 'ReadingTools.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['GlucosioConverter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'HistoryAdapter.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java']
# ['ReadingTools.java', 'A1cCalculatorActivity.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'A1cCalculatorActivity.java', 'OverviewPresenter.java']
# ['HistoryAdapter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddReadingActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddReadingActivity.java', 'AddA1CActivity.java', 'AddGlucoseActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'AddReadingActivity.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddReadingActivity.java', 'AddA1CActivity.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddA1CActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddWeightActivity.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddA1CActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'AddA1CActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddGlucoseActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddKetoneActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'HelloActivityTest.java', 'AddKetoneActivity.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddCholesterolActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java']
# ['AddReadingActivity.java', 'AddWeightActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'HistoryAdapter.java', 'GlucosioConverter.java', 'AddGlucoseActivity.java']
# ['ReadingTools.java', 'GlucosioConverter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['ReadingTools.java', 'HistoryAdapter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'AddReadingActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddKetoneActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'AddWeightActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['OverviewPresenter.java', 'HelloActivityTest.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'OverviewPresenter.java']
# ['AddWeightActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddWeightActivity.java', 'HelloActivityTest.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HelloActivityTest.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['HistoryAdapter.java', 'GlucosioConverter.java', 'ReadingTools.java', 'OverviewPresenter.java']
# ['GlucosioConverter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java', 'HistoryAdapter.java', 'A1cCalculatorActivity.java']
# ['GlucosioConverter.java', 'AddGlucoseActivity.java', 'HistoryAdapter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['GlucosioConverter.java', 'AddGlucoseActivity.java', 'OverviewPresenter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['AddGlucoseActivity.java', 'OverviewPresenter.java', 'HistoryAdapter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['GlucosioConverter.java', 'OverviewPresenter.java', 'HistoryAdapter.java', 'A1cCalculatorActivity.java', 'ReadingTools.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddReadingActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ...
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddReadingActivity.java', 'AddKetoneActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'AddReadingActivity.java', 'AddGlucoseActivity.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java']
# ['AddCholesterolActivity.java', 'AddKetoneActivity.java', 'GlucosioApplication.java', 'OverviewPresenter.java', 'OverviewFragment.java', 'AddWeightActivity.java', 'HelloActivityTest.java', 'AddPressureActivity.java', 'AddA1CActivity.java']

# %%
for r in rules_list:
  print(r)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# RelationRecord(items=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({"'AddA1CActivity.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'AddCholesterolActivity.java'"}), items_add=frozenset({"'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'AddKetoneActivity.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'AddPressureActivity.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddA1CActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'AddWeightActivity.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'GlucosioApplication.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({"'HelloActivityTest.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({"'OverviewFragment.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewPresenter.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=1.0, lift=3.0), OrderedStatistic(items_base=frozenset({"'OverviewPresenter.java'"}), items_add=frozenset({"'AddCholesterolActivity.java'", "'AddKetoneActivity.java'", "'GlucosioApplication.java'", "'OverviewFragment.java'", "'AddWeightActivity.java'", "'HelloActivityTest.java'", "'AddPressureActivity.java'", "'AddA1CActivity.java'"}), confidence=0.5, lift=1.5), OrderedStatistic(items_base=frozenset({"'AddCholesterolActivity.java'", "'AddA1CActivity.java'"}), items_add=frozenset({"'AddKetoneActivity.java'", "'GlucosioApplicat ...

# %% [markdown]
# We can observe the influence of setting different values of confidence and support.

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.1, min_support=0.1)
# Out:
# Nr rules 668, with structural coupling 615, 0.92

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.15, min_support=0.15)
# Out:
# Nr rules 668, with structural coupling 615, 0.92

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.05, min_support=0.1)
# Out:
# Nr rules 668, with structural coupling 615, 0.92

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.05, min_support=0.05)
# Out:
# Nr rules 668, with structural coupling 615, 0.92

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.6, min_support=0.6)
# Out:
# Nr rules 33, with structural coupling 26, 0.79

# %% [markdown]
# # Display transactions with given itemsets

# %%
l_elem = ['OverviewFragment.java', 'DatabaseHandler.java']
show_transactions_containing_items(df, 'files_in_hash',l_elem, print_elems=False)
# Out:
# Element count. Df len 7. 1ind: 1, 2dep: 0, 2ind: 0

# %%
l_elem = ['AddCholesterolActivity.java', 'AddA1CActivity.java']
show_transactions_containing_items(df,'files_in_hash', l_elem, print_elems=False)
# Out:
# Element count. Df len 7. 1ind: 2, 2dep: 2, 2ind: 2

# %%
l_elems = ["'AddKetoneActivity.java'", "'AddWeightActivity.java'", "'AddGlucoseActivity.java'", "'AddPressureActivity.java'"]
show_transactions_containing_items(df, 'files_in_hash', l_elems, print_elems=False)
# Out:
# Element count. Df len 7. 1ind: 2, 2dep: 2, 3dep: 1, 4dep: 1,
#     2ind: 2, 3ind: 2, 4ind: 2

# %% [markdown]
# ## On week

# %%
# apyori.apriori needs apostrophes around each of the values of the transaction
sql_statement = """select
strftime('%Y', date(commit_commiter_datetime)) as iso_yr,
(strftime('%j', date(commit_commiter_datetime, '-3 days', 'weekday 4')) - 1) / 7 + 1 as iso_week,
GROUP_CONCAT("'" || file_name|| "'") as files_in_week
--GROUP_CONCAT(distinct("'" || file_name|| "'") ) as files_in_week
from file_commit
group by strftime('%Y', date(commit_commiter_datetime)),
(strftime('%j', date(commit_commiter_datetime, '-3 days', 'weekday 4')) - 1) / 7 + 1;"""


records, pruned_records, df = get_records(con_analytics_db, 'files_in_week', sql_statement, 2)
# Out:
# df len:  5
# records len:  5
# pruned_records len:  2

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, records, min_confidence=0.1, min_support=0.1)
# Out:
# Nr rules 4155, with structural coupling 4091, 0.98

# %%
rules_list, itemsets_list = calculate_structural_coupling_rates(con_analytics_db, pruned_records, min_confidence=0.6, min_support=0.5)
# Out:
# Nr rules 4141, with structural coupling 4091, 0.99
